# %%
import sys
import os
workspace_path = os.path.join(os.path.abspath(".."))
sys.path.append(workspace_path)
workspace_path
# Out:
# 'c:\\Users\\Kajsa\\VSCodeProjects\\job_discrimination'

# %%
import pandas as pd
from pandas.core.frame import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
import re
import warnings
warnings.simplefilter("ignore")
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split, cross_val_score, ShuffleSplit
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree, preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import shap

# Local imports
from src.helpers import *

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
path_to_cleaned_data = os.path.join(workspace_path, "data", "cleaned_data")
file_dir = os.path.join(path_to_cleaned_data, "Job_Bulletins", "labeled", "*")
file_paths = glob.glob(file_dir)

# %%
# Reading application statistics into dataframe
file_path = os.path.join(path_to_cleaned_data, "applicants.csv")
df = pd.read_csv(file_path, dtype={"ID": str})
df
# Out:
#        ID                          Job Description  Apps Received  Female  \
# 0    9206                             311 DIRECTOR             54      20
# 1    1223                         ACCOUNTING CLERK            648     488
# 2    7260                          AIRPORT MANAGER             51      13
# 3    3227                AIRPORT POLICE LIEUTENANT             48       9
# 4    2400                                 AQUARIST             40      15
# ..    ...                                      ...            ...     ...
# 172  7840  WASTEWATER TREATMENT LABORATORY MANAGER             16       6
# 173  4123            WASTEWATER TREATMENT OPERATOR            125       9
# 174  7857                     WATER MICROBIOLOGIST            179      89
# 175  3912                     WATER UTILITY WORKER             96       2
# 176  1774             WORKERS COMPENSATION ANALYST            166     100
#
#      Male  Unknown_Gender                                         File Names
# 0      31               3                      311 DIRECTOR  9206 041814.txt
# 1     152               8                   ACCOUNTING CLERK 1223 071318.txt
# 2      37               1                    AIRPORT MANAGER 7260 120216.txt
# 3      38               1          AIRPORT POLICE LIEUTENANT 3227 091616.txt
# 4      24               1                           AQUARIST 2400 050214.txt
# ..    ...             ...                                                ...
# 172     9               1  WASTEWATER TREATMENT LABORATORY MANAGER 7840 1...
# 173   113               3           WASTEWATER TREATMENT OPERATOR 120718.txt
# 174    82               8    WATER MICROBIOLOGIST  7857 072514 rev073114.txt
# 175    92               2               WATER UTILITY WORKER 3912 120817.txt
# 176    61               5     WORKERS_ COMPENSATION ANALYST 1774 032417R.txt
#
# [177 rows x 7 columns]

# %%
# Replacing old file names with cleaned versions
df["File Names"] = df["Job Description"] + " " + df["ID"]
df
# Out:
#        ID                          Job Description  Apps Received  Female  \
# 0    9206                             311 DIRECTOR             54      20
# 1    1223                         ACCOUNTING CLERK            648     488
# 2    7260                          AIRPORT MANAGER             51      13
# 3    3227                AIRPORT POLICE LIEUTENANT             48       9
# 4    2400                                 AQUARIST             40      15
# ..    ...                                      ...            ...     ...
# 172  7840  WASTEWATER TREATMENT LABORATORY MANAGER             16       6
# 173  4123            WASTEWATER TREATMENT OPERATOR            125       9
# 174  7857                     WATER MICROBIOLOGIST            179      89
# 175  3912                     WATER UTILITY WORKER             96       2
# 176  1774             WORKERS COMPENSATION ANALYST            166     100
#
#      Male  Unknown_Gender                                    File Names
# 0      31               3                             311 DIRECTOR 9206
# 1     152               8                         ACCOUNTING CLERK 1223
# 2      37               1                          AIRPORT MANAGER 7260
# 3      38               1                AIRPORT POLICE LIEUTENANT 3227
# 4      24               1                                 AQUARIST 2400
# ..    ...             ...                                           ...
# 172     9               1  WASTEWATER TREATMENT LABORATORY MANAGER 7840
# 173   113               3            WASTEWATER TREATMENT OPERATOR 4123
# 174    82               8                     WATER MICROBIOLOGIST 7857
# 175    92               2                     WATER UTILITY WORKER 3912
# 176    61               5             WORKERS COMPENSATION ANALYST 1774
#
# [177 rows x 7 columns]

# %%
# Getting bulletin texts and lemmatizing them
file_names, contents = get_contents(file_paths)
contents_lemmatized = lemmatize(contents)

# %%
df_content = pd.DataFrame({"File Names": file_names, "lemmatized_contents": contents_lemmatized})

# %%
df_content
# Out:
#                                      File Names  \
# 0                             311 DIRECTOR 9206
# 1                         ACCOUNTING CLERK 1223
# 2                AIR CONDITIONING MECHANIC 3774
# 3                          AIRPORT MANAGER 7260
# 4                AIRPORT POLICE LIEUTENANT 3227
# ..                                          ...
# 172         WATERWORKS MECHANIC SUPERVISOR 3987
# 173                                 WELDER 3796
# 174                             WHARFINGER 1190
# 175           WORKERS COMPENSATION ANALYST 1774
# 176  WORKERS COMPENSATION CLAIMS ASSISTANT 1775
#
#                                    lemmatized_contents
# 0    director class code open date annual salary du...
# 1    accounting clerk class code open date exam ope...
# 2    air condition mechanic class code open date ex...
# 3    airport manager class code open date exam open...
# 4    airport police lieutenant class code open date...
# ..                                                 ...
# 172  waterworks mechanic supervisor class code open...
# 173  welder class code open date exam open include ...
# 174  wharfinger class code open date exam open incl...
# 175  worker compensation analyst class code open da...
# 176  worker compensation claim assistant class code...
#
# [177 rows x 2 columns]

# %%
df = df.merge(df_content, how="inner", on="File Names")

# %%
df
# Out:
#        ID                          Job Description  Apps Received  Female  \
# 0    9206                             311 DIRECTOR             54      20
# 1    1223                         ACCOUNTING CLERK            648     488
# 2    7260                          AIRPORT MANAGER             51      13
# 3    3227                AIRPORT POLICE LIEUTENANT             48       9
# 4    2400                                 AQUARIST             40      15
# ..    ...                                      ...            ...     ...
# 172  7840  WASTEWATER TREATMENT LABORATORY MANAGER             16       6
# 173  4123            WASTEWATER TREATMENT OPERATOR            125       9
# 174  7857                     WATER MICROBIOLOGIST            179      89
# 175  3912                     WATER UTILITY WORKER             96       2
# 176  1774             WORKERS COMPENSATION ANALYST            166     100
#
#      Male  Unknown_Gender                                    File Names  \
# 0      31               3                             311 DIRECTOR 9206
# 1     152               8                         ACCOUNTING CLERK 1223
# 2      37               1                          AIRPORT MANAGER 7260
# 3      38               1                AIRPORT POLICE LIEUTENANT 3227
# 4      24               1                                 AQUARIST 2400
# ..    ...             ...                                           ...
# 172     9               1  WASTEWATER TREATMENT LABORATORY MANAGER 7840
# 173   113               3            WASTEWATER TREATMENT OPERATOR 4123
# 174    82               8                     WATER MICROBIOLOGIST 7857
# 175    92               2                     WATER UTILITY WORKER 3912
# 176    61               5             WORKERS COMPENSATION ANALYST 1774
#
#                                    lemmatized_contents
# 0    director class code open date annual salary du...
# 1    accounting clerk class code open date exam ope...
# 2    airport manager class code open date exam open...
# 3    airport police lieutenant class code open date...
# 4    aquarist class code open date annual salary ca...
# ..                                                 ...
# 172  wastewater treatment laboratory manager class ...
# 173  wastewater treatment operator class code open ...
# 174  water microbiologist class code open date revi...
# 175  water utility worker class code open date exam...
# 176  worker compensation analyst class code open da...
#
# [177 rows x 8 columns]

# %%
# Create and add labels
mostly_women = df["Female"] >= (df["Apps Received"] - df["Unknown_Gender"]) * 0.6
mostly_men = df["Male"] >= (df["Apps Received"] - df["Unknown_Gender"]) * 0.6
neutral = (df["Female"] < (df["Apps Received"] - df["Unknown_Gender"]) * 0.6) & (df["Female"] > (df["Apps Received"] - df["Unknown_Gender"]) * 0.4)

# %%
labels = []
for i in range(len(df)):
    if mostly_women[i]:
        label = 1
    elif mostly_men[i]:
        label = 2
    elif neutral[i]:
        label = 0
    else:
        label = None
    labels.append(label)
df["Labels"] = labels

# %%
df["Labels"].value_counts()
# Out:
# 2    126
# 0     32
# 1     19
# Name: Labels, dtype: int64

# %%
df
# Out:
#        ID                          Job Description  Apps Received  Female  \
# 0    9206                             311 DIRECTOR             54      20
# 1    1223                         ACCOUNTING CLERK            648     488
# 2    7260                          AIRPORT MANAGER             51      13
# 3    3227                AIRPORT POLICE LIEUTENANT             48       9
# 4    2400                                 AQUARIST             40      15
# ..    ...                                      ...            ...     ...
# 172  7840  WASTEWATER TREATMENT LABORATORY MANAGER             16       6
# 173  4123            WASTEWATER TREATMENT OPERATOR            125       9
# 174  7857                     WATER MICROBIOLOGIST            179      89
# 175  3912                     WATER UTILITY WORKER             96       2
# 176  1774             WORKERS COMPENSATION ANALYST            166     100
#
#      Male  Unknown_Gender                                    File Names  \
# 0      31               3                             311 DIRECTOR 9206
# 1     152               8                         ACCOUNTING CLERK 1223
# 2      37               1                          AIRPORT MANAGER 7260
# 3      38               1                AIRPORT POLICE LIEUTENANT 3227
# 4      24               1                                 AQUARIST 2400
# ..    ...             ...                                           ...
# 172     9               1  WASTEWATER TREATMENT LABORATORY MANAGER 7840
# 173   113               3            WASTEWATER TREATMENT OPERATOR 4123
# 174    82               8                     WATER MICROBIOLOGIST 7857
# 175    92               2                     WATER UTILITY WORKER 3912
# 176    61               5             WORKERS COMPENSATION ANALYST 1774
#
#                                    lemmatized_contents  Labels
# 0    director class code open date annual salary du...       2
# 1    accounting clerk class code open date exam ope...       1
# 2    airport manager class code open date exam open...       2
# 3    airport police lieutenant class code open date...       2
# 4    aquarist class code open date annual salary ca...       2
# ..                                                 ...     ...
# 172  wastewater treatment laboratory manager class ...       2
# 173  wastewater treatment operator class code open ...       2
# 174  water microbiologist class code open date revi...       0
# 175  water utility worker class code open date exam...       2
# 176  worker compensation analyst class code open da...       1
#
# [177 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# ID                     0
# Job Description        0
# Apps Received          0
# Female                 0
# Male                   0
# Unknown_Gender         0
# File Names             0
# lemmatized_contents    0
# Labels                 0
# dtype: int64

# %%
df.dropna(how="any", inplace=True)
df.reset_index(inplace=True, drop=True)
df.drop(columns=["Apps Received", "Female", "Male", "Unknown_Gender"], inplace=True)

# %%
df
# Out:
#        ID                          Job Description  \
# 0    9206                             311 DIRECTOR
# 1    1223                         ACCOUNTING CLERK
# 2    7260                          AIRPORT MANAGER
# 3    3227                AIRPORT POLICE LIEUTENANT
# 4    2400                                 AQUARIST
# ..    ...                                      ...
# 172  7840  WASTEWATER TREATMENT LABORATORY MANAGER
# 173  4123            WASTEWATER TREATMENT OPERATOR
# 174  7857                     WATER MICROBIOLOGIST
# 175  3912                     WATER UTILITY WORKER
# 176  1774             WORKERS COMPENSATION ANALYST
#
#                                        File Names  \
# 0                               311 DIRECTOR 9206
# 1                           ACCOUNTING CLERK 1223
# 2                            AIRPORT MANAGER 7260
# 3                  AIRPORT POLICE LIEUTENANT 3227
# 4                                   AQUARIST 2400
# ..                                            ...
# 172  WASTEWATER TREATMENT LABORATORY MANAGER 7840
# 173            WASTEWATER TREATMENT OPERATOR 4123
# 174                     WATER MICROBIOLOGIST 7857
# 175                     WATER UTILITY WORKER 3912
# 176             WORKERS COMPENSATION ANALYST 1774
#
#                                    lemmatized_contents  Labels
# 0    director class code open date annual salary du...       2
# 1    accounting clerk class code open date exam ope...       1
# 2    airport manager class code open date exam open...       2
# 3    airport police lieutenant class code open date...       2
# 4    aquarist class code open date annual salary ca...       2
# ..                                                 ...     ...
# 172  wastewater treatment laboratory manager class ...       2
# 173  wastewater treatment operator class code open ...       2
# 174  water microbiologist class code open date revi...       0
# 175  water utility worker class code open date exam...       2
# 176  worker compensation analyst class code open da...       1
#
# [177 rows x 5 columns]

# %%
X = df["lemmatized_contents"]
y = df["Labels"]

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# Initializing a vectorizer in order to transform the text to numbers
# # Stop words already removed in "lemmatizer"?
# vect = CountVectorizer(stop_words="english")

vect = TfidfVectorizer()

# %%
# .todense() probably not applicable in this case, since no null-values are present
X = vect.fit_transform(X).todense()

# %%
type(X)
# Out:
# numpy.matrix

# %%
X.shape
X = X.A

# %%
type(X)
X = pd.DataFrame(X)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1000)

# %%
model = DecisionTreeClassifier(criterion="entropy", max_depth=4)

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 1, 0, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 2, 2, 2,
#        2], dtype=int64)

# %%
accuracy = accuracy_score(y_pred, y_test) * 100
print(f"Accuracy of the model is {'{:.2f}'.format(accuracy)}")
# Out:
# Accuracy of the model is 71.11

# %%
tree.plot_tree(model)
plt.show()

# %%
cm = confusion_matrix(y_true=y_test, y_pred=y_pred, labels=model.classes_)

# %%
plot = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
plot.plot()
plt.show()

# %%
scores = cross_val_score(model, X, y, cv=5)
scores
# Out:
# array([0.69444444, 0.58333333, 0.54285714, 0.77142857, 0.65714286])

# %%
# Standard deviation: The spread of values. 
# High standard deviation implies high spread of accuracies between cross-validation folds
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.65 accuracy with a standard deviation of 0.08

# %%
n_samples = X.shape[0]
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
other_scores = cross_val_score(model, X, y, cv=cv)
other_scores
# Out:
# array([0.66666667, 0.62962963, 0.62962963, 0.55555556, 0.68518519])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (other_scores.mean(), other_scores.std()))
# Out:
# 0.63 accuracy with a standard deviation of 0.04

# %%
# Fits the explainer
explainer = shap.Explainer(model.predict, X_test)

# %%
# Calculates the SHAP values - It takes some time
shap_values = explainer(X_test, max_evals=5000)
# Out:
# Permutation explainer: 46it [06:08,  8.36s/it]

# %%
shap.plots.bar(shap_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 shap.plots.bar(shap_values)
#
# File c:\Users\Kajsa\VSCodeProjects\job_discrimination\venv\lib\site-packages\shap\plots\_bar.py:207, in bar(shap_values, max_display, order, clustering, clustering_cutoff, merge_cohorts, show_data, show)
#     199     pl.barh(
#     200         y_pos + ypos_offset, values[i,feature_inds],
#     201         bar_width, align='center',
#     202         color=[colors.blue_rgb if values[i,feature_inds[j]] <= 0 else colors.red_rgb for j in range(len(y_pos))],
#     203         hatch=patterns[i], edgecolor=(1,1,1,0.8), label=f"{cohort_labels[i]} [{cohort_sizes[i] if i < len(cohort_sizes) else None}]"
#     204     )
#     206 # draw the yticks (the 1e-8 is so matplotlib 3.3 doesn't try and collapse the ticks)
# --> 207 pl.yticks(list(y_pos) + list(y_pos + 1e-8), yticklabels + [l.split('=')[-1] for l in yticklabels], fontsize=13)
#     209 xlen = pl.xlim()[1] - pl.xlim()[0]
#     210 fig = pl.gcf()
#
# File c:\Users\Kajsa\VSCodeProjects\job_discrimination\venv\lib\site-packages\shap\plots\_bar.py:207, in <listcomp>(.0)
#     199     pl.barh(
#     200         y_pos + ypos_offset, values[i,feature_inds],
#     201         bar_width, align='center',
#     202         color=[colors.blue_rgb if values[i,feature_inds[j]] <= 0 else colors.red_rgb for j in range(len(y_pos))],
#     203         hatch=patterns[i], edgecolor=(1,1,1,0.8), label=f"{cohort_labels[i]} [{cohort_sizes[i] if i < len(cohort_sizes) else None}]"
#     204     )
#     206 # draw the yticks (the 1e-8 is so matplotlib 3.3 doesn't try and collapse the ticks)
# --> 207 pl.yticks(list(y_pos) + list(y_pos + 1e-8), yticklabels + [l.split('=')[-1] for l in yticklabels], fontsize=13)
#     209 xlen = pl.xlim()[1] - pl.xlim()[0]
#     210 fig = pl.gcf()
#
# AttributeError: 'int' object has no attribute 'split'
